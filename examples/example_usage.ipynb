# %% [markdown]
# # Token Metrics AI API SDK - Example Usage
#
# This notebook demonstrates how to use the Token Metrics AI API Python SDK to access cryptocurrency data, trading signals, market metrics, and AI-powered insights.

# %% [markdown]
# ## Setup
#
# First, install the SDK if you haven't already:

# %%
# Uncomment to install
# !pip install tmai-api

# %% [markdown]
# Import the SDK and initialize the client:

# %%
from tmai_api import TokenMetricsClient
import pandas as pd
import matplotlib.pyplot as plt

# Initialize with your API key
client = TokenMetricsClient(api_key="YOUR-API-KEY")

# %% [markdown]
# ## Example 1: Get Token Information
#
# Let's retrieve information about specific tokens:

# %%
# Get information for Bitcoin and Ethereum
tokens = client.tokens.get(symbol="BTC,ETH")
print(f"Found {len(tokens.get('data', []))} tokens")

# Convert to DataFrame for easier exploration
tokens_df = client.tokens.get_dataframe(symbol="BTC,ETH")
tokens_df.head()
# Out:
# Found 18 tokens
#    TOKEN_ID                            TOKEN_NAME TOKEN_SYMBOL  \
# 0     31211             Bridged Ether (StarkGate)          ETH
# 1     31615  Bridged Binance-Peg Ethereum (opBNB)          ETH
# 2     33534                   The Infinite Garden          ETH
# 3     33649              BlackrockTradingCurrency          BTC
# 4     40225               Meld Bridged BTC (Meld)          BTC
#
#                                        EXCHANGE_LIST  \
# 0  [{'exchange_id': 'nostra', 'exchange_name': 'N...
# 1  [{'exchange_id': 'pancakeswap-v3-opbnb', 'exch...
# 2  [{'exchange_id': 'uniswap_v2', 'exchange_name'...
# 3  [{'exchange_id': 'uniswap_v2', 'exchange_name'...
# 4                                               None
#
#                                        CATEGORY_LIST  \
# 0  [{'category_id': 276, 'category_name': 'Starkn...
# 1  [{'category_id': 599, 'category_name': 'opBNB ...
# 2  [{'category_id': 143, 'category_name': 'Ethere...
# 3  [{'category_id': 89, 'category_name': 'Decentr...
# 4  [{'category_id': 573, 'category_name': 'Bridge...
#
#                               tm_link  \
# 0     bridged-wrapped-ether-starkgate
# 1  bridged-binance-peg-ethereum-opbnb
# 2                 the-infinite-garden
# 3            blackrocktradingcurrency
# 4               meld-bridged-btc-meld
#
#                                     contract_address  \
# 0  {'starknet': '0x49d36570d4e46f48e99674bd3fcc84...
# 1  {'opbnb': '0xe7798f023fc62146e8aa1b36da45fb708...
# 2  {'ethereum': '0x5e21d1ee5cf0077b314c381720273a...
# 3  {'ethereum': '0xbd6323a83b613f668687014e8a5852...
# 4  {'meld': '0x333008cfcbfbefffbb546abf237adc4061...
#
#                                   TM_LINK
# 0  https://app.tokenmetrics.com/undefined
# 1  https://app.tokenmetrics.com/undefined
# 2  https://app.tokenmetrics.com/undefined
# 3  https://app.tokenmetrics.com/undefined
# 4  https://app.tokenmetrics.com/undefined

# %% [markdown]
# ## Example 2: Get Hourly OHLCV Data
#
# Get price and volume data for the last 7 days:

# %%
from datetime import datetime, timedelta

# Calculate dates for last 7 days
end_date = datetime.now().strftime("%Y-%m-%d")
start_date = (datetime.now() - timedelta(days=7)).strftime("%Y-%m-%d")

# Get OHLCV data
ohlcv_data = client.hourly_ohlcv.get(
    symbol="BTC",
    startDate=start_date,
    endDate=end_date
)

# Convert to DataFrame
ohlcv_df = client.hourly_ohlcv.get_dataframe(
    symbol="BTC",
    startDate=start_date,
    endDate=end_date
)

# Display the most recent data
ohlcv_df.head()
# Out:
#    TOKEN_ID      TOKEN_NAME TOKEN_SYMBOL                 TIMESTAMP  \
# 0     35621          batcat          BTC  2025-03-25T23:25:22.064Z
# 1      3375         Bitcoin          BTC  2025-03-25T23:25:22.064Z
# 2     39218  Osmosis allBTC          BTC  2025-03-25T23:25:22.064Z
# 3     35621          batcat          BTC  2025-03-25T22:25:25.899Z
# 4     39218  Osmosis allBTC          BTC  2025-03-25T22:25:25.899Z
#
#            OPEN          HIGH           LOW         CLOSE        VOLUME
# 0      0.000034      0.000034      0.000034      0.000034  4.464748e+02
# 1  87448.000000  87651.000000  87398.000000  87651.000000  3.014219e+10
# 2  87298.000000  87298.000000  87166.000000  87293.000000  3.032165e+06
# 3      0.000035      0.000035      0.000034      0.000035  4.508780e+02
# 4  87881.000000  87881.000000  87688.000000  87828.000000  3.056436e+06

# %% [markdown]
# ## Example 3: Get Trader Grades
#
# Let's get the short-term trading grades for various tokens:

# %%
# Get trader grades for top coins
trader_grades = client.trader_grades.get(
    symbol="BTC,ETH,SOL,BNB,XRP",
    startDate=start_date,
    endDate=end_date
)

# Convert to DataFrame
trader_grades_df = client.trader_grades.get_dataframe(
    symbol="BTC,ETH,SOL,BNB,XRP",
    startDate=start_date,
    endDate=end_date
)

trader_grades_df.head()
# Out:
#    TOKEN_ID                  TOKEN_NAME TOKEN_SYMBOL  \
# 0      3375                     Bitcoin          BTC
# 1      3306                    Ethereum          ETH
# 2     35621                      batcat          BTC
# 3     39220              Osmosis allETH          ETH
# 4     30244  HarryPotterObamaPacMan8Inu          XRP
#
#                        DATE  TA_GRADE  QUANT_GRADE  TM_TRADER_GRADE  \
# 0  2025-03-26T00:00:00.000Z     81.90        60.81            77.68
# 1  2025-03-26T00:00:00.000Z     37.60        55.75            41.23
# 2  2025-03-26T00:00:00.000Z     29.63        40.61            31.83
# 3  2025-03-26T00:00:00.000Z     37.60        45.65            39.21
# 4  2025-03-26T00:00:00.000Z     81.90        44.76            74.47
#
#    TM_TRADER_GRADE_24H_PCT_CHANGE
# 0                           -0.36
# 1                           -0.03
# 2                           11.73
# 3                           -0.10
# 4                           -0.36

# %% [markdown]
# ## Example 4: Investor Grades
#
# Let's get the long-term investment grades:

# %%
# Get investor grades for the same tokens
investor_grades_df = client.investor_grades.get_dataframe(
    symbol="BTC, ETH",
    startDate=start_date,
    endDate=end_date
)

investor_grades_df.head()
# Out:
#    TOKEN_ID                       TOKEN_NAME TOKEN_SYMBOL  \
# 0     41627  Bridged Wrapped Ether (Eclipse)          ETH
# 1      3306                         Ethereum          ETH
# 2      3375                          Bitcoin          BTC
# 3     21994              Ethereum (Wormhole)          ETH
# 4     31211        Bridged Ether (StarkGate)          ETH
#
#                        DATE  TM_INVESTOR_GRADE  \
# 0  2025-03-26T00:00:00.000Z              50.00
# 1  2025-03-26T00:00:00.000Z              62.88
# 2  2025-03-26T00:00:00.000Z              58.94
# 3  2025-03-26T00:00:00.000Z              50.00
# 4  2025-03-26T00:00:00.000Z              50.00
#
#    TM_INVESTOR_GRADE_7D_PCT_CHANGE  FUNDAMENTAL_GRADE  TECHNOLOGY_GRADE  \
# 0                              NaN                NaN               NaN
# 1                             4.64               82.3             93.49
# 2                            -1.64               84.1             78.42
# 3                              NaN                NaN               NaN
# 4                              NaN                NaN               NaN
#
#    VALUATION_GRADE  DEFI_USAGE_SCORE  COMMUNITY_SCORE  EXCHANGE_SCORE  \
# 0              NaN               NaN              NaN             NaN
# 1              8.0              9.17         8.271481            10.0
# 2              8.0              8.33         8.322292            10.0
# 3              NaN               NaN              NaN             NaN
# 4              NaN               NaN              NaN             NaN
#
#   VC_SCORE  TOKENOMICS_SCORE  DEFI_SCANNER_SCORE  ACTIVITY_SCORE  \
# 0     None               NaN                 NaN             NaN
# 1     None          6.000000                10.0            9.66
# 2     None          7.333333                 NaN            8.73
# 3     None               NaN                 NaN             NaN
# 4     None               NaN                 NaN             NaN
#
#   SECURITY_SCORE  REPOSITORY_SCORE  COLLABORATION_SCORE
# 0           None               NaN                  NaN
# 1           None               7.2                 10.0
# 2           None               7.9                  6.6
# 3           None               NaN                  NaN
# 4           None               NaN                  NaN

# %% [markdown]
# ## Example 5: Market Metrics
#
# Get overall market sentiment data:

# %%
# Get market metrics
market_metrics_df = client.market_metrics.get_dataframe(
    startDate=start_date,
    endDate=end_date
)

market_metrics_df.head()

# %% [markdown]
# ## Example 6: Trader Indices
#
# Get the AI-generated trading portfolios:

# %%
# Get trader indices
trader_indices_df = client.trader_indices.get_dataframe(
    startDate=start_date,
    endDate=end_date
)

trader_indices_df.head()
# Out:
#   PORTFOLIO_DATE  TOKEN_ID      TOKEN_NAME TOKEN_SYMBOL  INDEX_WEIGHT  \
# 0     2025-03-26     41628        BugsCoin         BGSC      0.054748
# 1     2025-03-26     32137  Fimarkcoin.com          FMC      0.051283
# 2     2025-03-26     29421    Cheems Token       CHEEMS      0.057103
# 3     2025-03-26     36706  Ekubo Protocol        EKUBO      0.269152
# 4     2025-03-26     42646           Plume        PLUME      0.036185
#
#    INITIAL_PRICE  AMOUNT_OF_TOKENS
# 0       0.008533      6.415902e+04
# 1       0.002115      2.424322e+05
# 2       0.000002      2.812953e+08
# 3       7.050000      3.817761e+02
# 4       0.193012      1.874778e+03

# %% [markdown]
# ## Example 7: AI Agent (Chatbot)
#
# Let's interact with the Token Metrics AI chatbot:

# %%
# Ask a simple question
question = "What is the next 100x coin?"
response = client.ai_agent.ask(question)

# Print the full response
import json
print(json.dumps(response, indent=2))

# Get just the answer text
answer = client.ai_agent.get_answer_text(question)
print(f"\nAI says: {answer}")
# Out:
# {
#   "success": true,
#   "message": "AI Chatbot response successful",
#   "answer": "Predicting the next 100x coin is speculative, but here are some contenders based on current trends and potential: Polygon is making waves with its expanding Web3 adoption and strategic partnerships with giants like Disney and Nike. Arbitrum is gaining traction in DeFi, addressing Ethereum's congestion issues, and collaborating with major DeFi protocols. Thorchain is poised to lead in blockchain interoperability, crucial for the growing demand for cross-chain trading. Gala Games is tapping into the Web3 gaming boom, with a strong foothold in the NFT and play-to-earn markets. Always do your own research and consider the risks before investing!",
#   "thread": [
#     {
#       "user": "What is the next 100x coin?"
#     },
#     {
#       "chatbot": "Predicting the next 100x coin is speculative, but here are some contenders based on current trends and potential: Polygon is making waves with its expanding Web3 adoption and strategic partnerships with giants like Disney and Nike. Arbitrum is gaining traction in DeFi, addressing Ethereum's congestion issues, and collaborating with major DeFi protocols. Thorchain is poised to lead in blockchain interoperability, crucial for the growing demand for cross-chain trading. Gala Games is tapping into the Web3 gaming boom, with a strong foothold in the NFT and play-to-earn markets. Always do your own research and consider the risks before investing!"
#     }
#   ]
# }
#
# AI says: Predicting the next 100x coin is highly speculative, but here are some intriguing contenders: Pepe Unchained leverages Ethereum Layer-2 for low-fee staking and has strong community support, aligning with the meme coin trend. Dawgz AI combines meme culture with AI solutions, featuring a deflationary model and active community engagement. Thorchain offers cross-chain liquidity, tapping into the growing demand for interoperability. Arbitrum addresses Ethereum's scalability issues with fast transactions and strong developer activity. Gala Games is expanding in the NFT gaming space, with popular titles boosting its ecosystem. Always do your own research and consider the risks before investing!

# %% [markdown]
# ## Example 8: AI Reports
#
# Get the latest AI-generated trading and investment reports:

# %%
# Get AI reports for Bitcoin and Ethereum
ai_reports = client.ai_reports.get(symbol="BTC,ETH")
print(f"Found {len(ai_reports.get('data', []))} reports")

# Convert to DataFrame
ai_reports_df = client.ai_reports.get_dataframe(symbol="BTC,ETH")
ai_reports_df.head()
# Out:
# Found 2 reports
#   TOKEN_ID TOKEN_NAME SYMBOL  \
# 0     3306   Ethereum    ETH
# 1     3375    Bitcoin    BTC
#
#                                        TRADER_REPORT  \
# 0  ## Introduction\n\nIn this report, we will ana...
# 1  ## Introduction\n\nIn this report, we will ana...
#
#                                   FUNDAMENTAL_REPORT  \
# 0  ## Introduction\n\nEthereum, known for its sma...
# 1  ## Introduction\n\nBitcoin is the pioneer cryp...
#
#                                    TECHNOLOGY_REPORT
# 0  ## Development Activity\n- **Total Commits for...
# 1  ## Development Activity\n\n  - Total Commits f...

# %% [markdown]
# ## Example 9: Trading Signals
#
# Get the AI-generated trading signals for long and short positions:

# %%
# Get trading signals for Bitcoin and Ethereum
trading_signals = client.trading_signals.get(
    symbol="BTC,ETH",
    startDate=start_date,
    endDate=end_date,
    signal="1"  # Bullish signals
)

# Convert to DataFrame
trading_signals_df = client.trading_signals.get_dataframe(
    symbol="BTC,ETH",
    startDate=start_date,
    endDate=end_date,
    signal="1"  # Bullish signals
)

trading_signals_df.head()
# Out:
#    TOKEN_ID      TOKEN_NAME TOKEN_SYMBOL                      DATE  \
# 0      3375         Bitcoin          BTC  2025-03-26T00:00:00.000Z
# 1     39218  Osmosis allBTC          BTC  2025-03-26T00:00:00.000Z
# 2      3375         Bitcoin          BTC  2025-03-25T00:00:00.000Z
# 3     39218  Osmosis allBTC          BTC  2025-03-25T00:00:00.000Z
#
#    TRADING_SIGNAL  TOKEN_TREND  TRADING_SIGNALS_RETURNS  HOLDING_RETURNS  \
# 0               1            1               47639.7508        7997.8991
# 1               1            1                  -0.0142           0.4980
# 2               1            1               47639.7508        7997.8991
# 3               1            1                  -0.0142           0.4980
#
#           tm_link  TM_TRADER_GRADE  TM_INVESTOR_GRADE  \
# 0         bitcoin            77.68              58.94
# 1  osmosis-allbtc            79.45              50.00
# 2         bitcoin            77.68              58.94
# 3  osmosis-allbtc            79.45              50.00
#
#                                   TM_LINK
# 0  https://app.tokenmetrics.com/undefined
# 1  https://app.tokenmetrics.com/undefined
# 2  https://app.tokenmetrics.com/undefined
# 3  https://app.tokenmetrics.com/undefined

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrated how to use the Token Metrics AI API SDK to access various cryptocurrency data, metrics, and AI-powered tools. You can use this data for trading signal generation, portfolio optimization, or market analysis.
#
# For more information, refer to the [official documentation](https://api.tokenmetrics.com/docs).
